# %%
import scipy.signal
import matplotlib.pyplot as plt
import numpy as np
import librosa

# %%
for file, title in [
    ("original.wav", "Original"),
    ("temporal_audio_vae.wav", "Ours"),
    ("rave_vae.wav", "RAVE (VAE)"),
    ("rave.wav", "RAVE (VAE + GAN)"),
]:
    x, fs = librosa.load(file)
    D = librosa.stft(x, hop_length=int(fs / 100))  # STFT of y
    S_db = librosa.amplitude_to_db(np.abs(D), ref=np.max)
    plt.figure()
    plt.title(title)
    librosa.display.specshow(S_db)
    plt.savefig(file+".png")
